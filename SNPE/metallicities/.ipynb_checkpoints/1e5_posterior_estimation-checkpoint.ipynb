# %% [markdown]
# ## SNPE applied to SFH
#
# We want to infer the percentiles of stellar mass of galaxies from their spectra (whose dimensions have been reduced using an autoencoder with an attention module from 4300 points to 16-component latent vectors)

# %% [markdown]
# We load the modules

# %%
import numpy as np
import matplotlib.pyplot as plt

#!pip install corner
#!pip --disable-pip-version-check install sbi


import torch
from sbi import utils as Ut
from sbi import inference as Inference
import pickle
from tqdm import tqdm

# %% [markdown]
# We load the percentiles and metallicities (y) and latent vectors

# %%
latents_batch=np.load('../input_dataset/latents_270000.npy',allow_pickle=True)
y=np.load('../input_dataset/y_270000.npy',allow_pickle=True)
latents=np.zeros((270000,16))
batch_size=512 

#to create a single dataset with all the minibatches
for j in range(len(latents_batch)):
    for i,x in enumerate(latents_batch[j]):
        latents[batch_size*j+i,:]=x
        
print(np.shape(latents))
print(np.shape(y))

#for checking distributions
for i in range(10):
    plt.hist(y[:,i],bins=20)
    if i <9:
        plt.title('Percentile '+str((i+1)*10)+' %')
        plt.xlabel('Time [Gyr]')
    else:
        plt.xlabel('Metallicity')
    plt.show()
    
for i in range(16):
    plt.hist(latents[:,i],bins=40,label='l'+str(i+1))
#plt.legend()
plt.title('latent components ')
plt.show()
# Out:
# (270000, 16)
# (270000, 10)

# %%
for i in range(9):
    plt.hist(y[:,i],bins=150)
    plt.title('Percentile '+str((i+1)*10)+' %')
    plt.xlabel('Time [Gyr]')
    plt.show()

# %% [markdown]
# We shuffle and save the indexes shuffled, or we just load them

# %%
#training with the first 243.000 elements of the dataset (previously shuffled) - 90% 

#index_sh=np.arange(270000)
#np.random.shuffle(index_sh)
#np.save('index_sh_met.npy',index_sh)
index_sh=np.load('../saved_models/index_sh_met.npy')

x=latents[index_sh[:243000],:]
theta=y[index_sh[:243000],:]

# %% [markdown]
# We define the range for the posterior estimation (wrongly called prior) - all of them uniformly distributed between 0 and 14

# %%
lower_bounds = -2*torch.ones(np.shape(theta[0,:]))
upper_bounds = 16*torch.ones(np.shape(theta[0,:]))
lower_bounds[-1]=-2.5
upper_bounds[-1]=0.5

print(lower_bounds)
print(upper_bounds)
bounds = Ut.BoxUniform(low=lower_bounds, high=upper_bounds, device='cpu')
# Out:
# tensor([-2.0000, -2.0000, -2.0000, -2.0000, -2.0000, -2.0000, -2.0000, -2.0000,
#         -2.0000, -2.5000])
# tensor([16.0000, 16.0000, 16.0000, 16.0000, 16.0000, 16.0000, 16.0000, 16.0000,
#         16.0000,  0.5000])

# %% [markdown]
# We define the model and train, then save the model

# %%
nhidden = 128 
nblocks = 5
maf_model = Ut.posterior_nn('maf', hidden_features=nhidden, num_transforms=nblocks)

anpe = Inference.SNPE(prior=bounds,
                      density_estimator=maf_model,
                      device='cpu')

#anpe, amortized neural posterior estimation
anpe.append_simulations(
            torch.as_tensor(theta.astype(np.float32)).to('cpu'),
            torch.as_tensor(x.astype(np.float32)).to('cpu'))  

# estimate p(theta|X), the posterior
p_theta_x_est = anpe.train()
qphi = anpe.build_posterior(p_theta_x_est)
# Out:
#  Neural network successfully converged after 179 epochs.

# %% [markdown]
# Save posterior or load it

# %%
file="./my_posterior_met.pkl"


with open(file, "wb") as handle:
    pickle.dump(qphi, handle)

handle.close()

"""
file = open(file, 'rb')
qphi = pickle.load(file)
file.close()
"""
# Out:
# "\nfile = open(file, 'rb')\nqphi = pickle.load(file)\nfile.close()\n"

# %% [markdown]
# We create a function to see real vs predicted percentiles and metallicities (we plot the mean and the interval of confidence: sigma, 2sigma... of the posteriors) for the test dataset (27.000 samples)

# %%
def plot_percentile_distribution(i,index_list=np.random.randint(243000,270000,15),mean=False,real_plot=False):
    
    if i==None:
        for k,j in enumerate(index_list):
                #if index_sh[j]>5000:
                Xobs=latents[index_sh[j],:]
                posterior_samples= np.array(qphi.sample((10000,), 
                                                    x=torch.as_tensor(np.array([Xobs]).astype(np.float32)).to('cpu'), 
                                                        show_progress_bars=False).detach().to('cpu'))
                
                plt.plot(y[index_sh[j],:9],np.arange(10,100,10),'.-',color='C'+str(k),label='real index '+str(index_sh[j]))
                plt.plot(np.mean(posterior_samples[:,:9],axis=0),np.arange(10,100,10),'.--',color='C'+str(k),label='predicted index '+str(index_sh[j]))
                plt.fill_betweenx(np.arange(10,100,10),np.mean(posterior_samples[:,:9],axis=0)+2*np.std(posterior_samples[:,:9],axis=0),np.mean(posterior_samples[:,:9],axis=0)-2*np.std(posterior_samples[:,:9],axis=0),color='C'+str(k),alpha=0.3,label='$2\\sigma$')
                plt.fill_betweenx(np.arange(10,100,10),np.mean(posterior_samples[:,:9],axis=0)+np.std(posterior_samples[:,:9],axis=0),np.mean(posterior_samples[:,:9],axis=0)-np.std(posterior_samples[:,:9],axis=0),color='C'+str(k),alpha=0.5,label='$\\sigma$')
                plt.title('Percentiles')
                plt.legend()
                plt.xlabel('Time [Gyr]')
                plt.ylabel('Mass / Total Mass [%]')
                #plt.savefig('prediction_1e5_m216_'+str(k)+'.jpg')
                plt.show()

        
    else:
         for k,j in enumerate(index_list):
                #if index_sh[j]>5000:
                Xobs=latents[index_sh[j],:]
                posterior_samples= np.array(qphi.sample((10000,), 
                                                    x=torch.as_tensor(np.array([Xobs]).astype(np.float32)).to('cpu'), 
                                                        show_progress_bars=False).detach().to('cpu'))

                plt.hist(posterior_samples[:,i-1],alpha=0.5,color='C'+str(k),label='index '+str(index_sh[j]))

                if mean:
                    plt.axvline(np.mean(posterior_samples[:,i-1]),ls='--',color='C'+str(k))
                    plt.axvline(y[index_sh[j],i-1],ls='-',color='C'+str(k))
         
        
         plt.title('percentil posterior ' +str(i*10)+'%')
         #plt.legend()
         plt.xlabel('Time [Gyr]')
         plt.show()
            
         if real_plot:
            for k,j in enumerate(index_list):
                #if index_sh[j]>5000:
                plt.plot(y[index_sh[j],:9],np.arange(10,100,10),'.-',color='C'+str(k),label='index '+str(index_sh[j]))
            plt.title('Real percentiles')
            plt.xlabel('Time [Gyr]')
            plt.ylabel('Mass / Total Mass [%]')
            #plt.legend()
            plt.show()
    

    
#plot_percentile_distribution(1,mean=True)
#plot_percentile_distribution(5,mean=True)
#plot_percentile_distribution(9,mean=True,real_plot=True)
plot_percentile_distribution(None)

# %% [markdown]
# We plot the mean of the predicted posteriors (and save it after computed) vs the ground truth

# %%
n_evaluations=27000
n_samples=1000
index_list=np.arange(243000,270000)

stds=[]
means=[]
#modas=[]
#medians=[]
for k,j in tqdm(enumerate(index_list)):
    Xobs=latents[index_sh[j],:]
    posterior_samples= np.array(qphi.sample((n_samples,), x=torch.as_tensor(np.array([Xobs]).astype(np.float32)).to('cpu'), show_progress_bars=False).detach().to('cpu'))
    stds.append(np.std(posterior_samples,axis=0))
    means.append(np.mean(posterior_samples,axis=0))
    #modas.append(np.mean(posterior_samples,axis=0))
    #medians.append(np.median(posterior_samples,axis=0))
    
np.save('means_met_full.npy',means)
np.save('stds_met_full.npy',stds)
# Out:
# 27000it [2:18:05,  3.26it/s]

# %%
means=np.load('means_met_full.npy')
stds=np.load('stds_met_full.npy')

#all together
plt.figure(figsize=(10,8))

for i in range(9):
    if i==0:
        plt.plot(np.arange(14),np.arange(14),label='y=x',color='k')
        plt.scatter(y[index_sh[index_list],i],means[:,i],s=1,color='b',label='Test dataset')#,label=str((i+1)*10)+' %')
    else:
        plt.scatter(y[index_sh[index_list],i],means[:,i],s=1,color='b')#,label=str((i+1)*10)+' %')


        
plt.xlabel('Real time [Gyr]',fontsize=20)
plt.ylabel('Predicted time [Gyr]',fontsize=20)
plt.legend(fontsize=10)
plt.title('Percentiles',fontsize=20)
#plt.savefig('1e5_m216_pred_vs_true.jpg')
plt.show()


#metallcitity

plt.plot(np.arange(-2.5,0.5,0.1),np.arange(-2.5,0.5,0.1),label='y=x',color='k')
plt.scatter(y[index_sh[index_list],-1],means[:,-1],s=1,color='b',label='Test dataset')
plt.xlabel('Real metallicity',fontsize=20)
plt.ylabel('Predicted metallicity',fontsize=20)
plt.legend(fontsize=10)
plt.title('Metallicities [M/H]',fontsize=20)

#one by one
for i in range(9):
    p=y[index_sh[index_list],i]
    x=np.arange(np.min(p)-0.5,np.max(p)+0.5)
    plt.figure(figsize=(8,5))
    plt.scatter(p,means[:,i],s=1,color='r',label='Test dataset')
    plt.plot(x,x,label='y=x',color='b')
    plt.xlabel('Real time [Gyr]')
    plt.ylabel('Predicted time [Gyr]')
    plt.legend()
    plt.title('Percentile '+str((i+1)*10)+' %')
    #plt.savefig('1e5_m216_prediction'+str(i)+'.jpg')
    plt.show()

# %% [markdown]
# See how many values outside each interval of confidence (for at least one percentile or averaging )

# %%
#fraction of galaxies with at least 1 percentil with error outside the 1sigma interval

stds=np.array(stds)
means=np.array(means)

indexes=[]
for k,j in enumerate(index_list):
    #print('k:', k)
    for i in range(10):
        #print('i: ',i)
        if stds[k,i]<(np.abs(means[k,i]-y[index_sh[j],i])):
            indexes.append(j)
            break

print('Fraction of galaxies with at least 1 percentil with error outside the 1sigma interval')
print(len(indexes)/n_evaluations * 100, '%')


      
#fraction of galaxies with at least 1 percentil with error outside the 2sigma interval

indexes=[]
for k,j in enumerate(index_list):
    for i in range(10):
        if 2*stds[k,i]<(np.abs(means[k,i]-y[index_sh[j],i])):
            indexes.append(j)
            break

print('Fraction of galaxies with at least 1 percentil with error outside the 2sigma interval')
print(len(indexes)/n_evaluations * 100, '%')

#the same but averaged between all percentiles

#sigma
indexes=[]
for k,j in enumerate(index_list):
        if np.mean(stds[k,:])<np.mean(np.abs(means[k,:]-y[index_sh[j],:])):
            indexes.append(j)

print('Fraction of galaxies with averaged error outside the averaged 1sigma interval')
print(len(indexes)/n_evaluations * 100, '%')

#2sigma
indexes=[]
for k,j in enumerate(index_list):
        if 2*np.mean(stds[k,:])<np.mean(np.abs(means[k,:]-y[index_sh[j],:])):
            indexes.append(j)
            
print('Fraction of galaxies with averaged error outside the averaged 2sigma interval')
print(len(indexes)/n_evaluations * 100, '%')

#the same but only for metallicity

#sigma
indexes=[]
for k,j in enumerate(index_list):
        if np.mean(stds[k,:])<np.mean(np.abs(means[k,:]-y[index_sh[j],:])):
            indexes.append(j)

print('Fraction of galaxies with metallicity error outside the averaged 1sigma interval')
print(len(indexes)/n_evaluations * 100, '%')

#2sigma
indexes=[]
for k,j in enumerate(index_list):
        if 2*stds[k,-1]< np.abs(means[k,-1]-y[index_sh[j],-1]):
            indexes.append(j)
            
print('Fraction of galaxies with metallicity error outside the averaged 2sigma interval')
print(len(indexes)/n_evaluations * 100, '%')
# Out:
# Fraction of galaxies with at least 1 percentil with error outside the 1sigma interval
# 44.333333333333336 %
# Fraction of galaxies with at least 1 percentil with error outside the 2sigma interval
# 4.0851851851851855 %
# Fraction of galaxies with averaged error outside the averaged 1sigma interval
# 22.007407407407406 %
# Fraction of galaxies with averaged error outside the averaged 2sigma interval
# 1.3444444444444446 %
# Fraction of galaxies with metallicity error outside the averaged 1sigma interval
# 22.007407407407406 %
# Fraction of galaxies with metallicity error outside the averaged 2sigma interval
# 0.6814814814814816 %

# %% [markdown]
# Corner plot

# %%
#all percentiles together

import corner

best_list=np.random.randint(243000,270000,5)

fig=plt.figure(figsize=(20,20))

posteriors=[]

for k,j in tqdm(enumerate(best_list)):
    print('index: ',index_sh[j])
    Xobs=latents[index_sh[j],:]
    posterior_samples = np.array(qphi.sample((10000,), 
                                    x=torch.as_tensor(np.array([Xobs]).astype(np.float32)).to('cpu'), 
                                    show_progress_bars=False).detach().to('cpu'))
    posteriors.append(posterior_samples)
    #qphi sample is the number of datapoints you want in the plot                            
    #print(np.shape(posterior_samples))

    lt=['p'+str(i*10) for i in range(1,10)] #label for percentiles
    lt.append('[M/H]')
    #we plot all the percentiles
    _ = corner.corner(posterior_samples[:,:], 
                      labels=lt,
                      label_kwargs={'fontsize': 25},
                      color='C'+str(k), hist_kwargs={'density': True},fig=fig)
    plt.fill_between([], [], [], color='C'+str(k), label="index"+str(index_sh[j]))
    
plt.legend(loc='upper left', fontsize=10)
plt.title('Normalizing flows \n'+ r'$q_\phi(\theta|X_{\rm obs})$',fontsize=20)
plt.show()
# Out:
# 0it [00:00, ?it/s]
# index:  218560
# 1it [00:09,  9.23s/it]
# index:  236109
# 2it [00:13,  6.34s/it]
# index:  195442
# 3it [00:18,  5.51s/it]
# index:  97916
# 4it [00:22,  5.09s/it]
# index:  228314
# 5it [00:26,  5.33s/it]

# %%
#all percentiles together

import corner

best_list=np.random.randint(243000,270000,5)

fig=plt.figure(figsize=(20,20))

posteriors=[]

for k,j in tqdm(enumerate(best_list)):
    print('index: ',index_sh[j])
    Xobs=latents[index_sh[j],:]
    posterior_samples = np.array(qphi.sample((10000,), 
                                    x=torch.as_tensor(np.array([Xobs]).astype(np.float32)).to('cpu'), 
                                    show_progress_bars=False).detach().to('cpu'))
    posteriors.append(posterior_samples)
    #qphi sample is the number of datapoints you want in the plot                            
    #print(np.shape(posterior_samples))

    lt=['p'+str(i*10) for i in range(1,10)] #label for percentiles
    lt.append('[M/H]')
    #we plot all the percentiles
    _ = corner.corner(posterior_samples[:,:], 
                      labels=lt,
                      label_kwargs={'fontsize': 25},
                      color='C'+str(k), hist_kwargs={'density': True},fig=fig)
    plt.fill_between([], [], [], color='C'+str(k), label="index"+str(index_sh[j]))
    
plt.legend(loc='upper left', fontsize=10)
plt.title('Normalizing flows \n'+ r'$q_\phi(\theta|X_{\rm obs})$',fontsize=20)
plt.show()
# Out:
# 0it [00:00, ?it/s]
# index:  40142
# 1it [00:08,  8.47s/it]
# index:  262959
# 2it [00:13,  6.71s/it]
# index:  145078
# 3it [00:17,  5.49s/it]
# index:  28167
# 4it [00:21,  4.90s/it]
# index:  211220
# 5it [00:25,  5.14s/it]

# %%
plt.hist(means[:,-1],bins=10,color='r',alpha=0.3)
plt.hist(y[index_sh,:][243000:,-1],bins=10,color='b',alpha=0.3)
plt.show()

plt.hist(means[:,-1],bins=100,color='r',alpha=0.3)
plt.hist(y[index_sh,:][243000:,-1],bins=100,color='b',alpha=0.3)
plt.show()

# %%
print(index_sh)

ind=40142

print(np.where(index_sh==ind)[0])
x=np.where(index_sh==ind)[0]
print(y[ind,-1], means[x-243000,-1],stds[x-243000,-1])

ind=262959
x=np.where(index_sh==ind)[0]
print(y[ind,-1], means[x-243000,-1],stds[x-243000,-1])

ind=145078
x=np.where(index_sh==ind)[0]
print(y[ind,-1], means[x-243000,-1],stds[x-243000,-1])

ind=28167
x=np.where(index_sh==ind)[0]
print(y[ind,-1], means[x-243000,-1],stds[x-243000,-1])

ind=211220
x=np.where(index_sh==ind)[0]
print(y[ind,-1], means[x-243000,-1],stds[x-243000,-1])
# Out:
# [135055 170193 237620 ... 218187 192901 110876]
# [252031]
# -1.8999999999999995 [-1.9053594] [0.01894366]
# 0.3000000000000025 [0.26903796] [0.04139328]
# -0.8999999999999986 [-0.88988894] [0.01741421]
# -2.0999999999999996 [-2.0741894] [0.05986279]
# -0.19999999999999796 [-0.1980145] [0.01707488]
